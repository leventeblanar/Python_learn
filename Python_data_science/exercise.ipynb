# %%
import pandas as pd

# %% [markdown]
# 1. feladat

# %%
df = pd.read_csv('customer.csv')

df.head(5)
# Out:
#    customer_id first_name    last_name  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
#
#                            address                 city state         country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo   NaN          Norway
# ...

# %% [markdown]
# 2. feladat

# %%
df.shape
# Out:
# (59, 13)

# %% [markdown]
# 3. feladat

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'company', 'address', 'city',
#        'state', 'country', 'postal_code', 'phone', 'fax', 'email',
#        'support_rep_id'],
#       dtype='object')

# %% [markdown]
# 4. feladat

# %%
df.dtypes
# Out:
# customer_id        int64
# first_name        object
# last_name         object
# company           object
# address           object
# city              object
# state             object
# country           object
# postal_code       object
# phone             object
# fax               object
# email             object
# support_rep_id     int64
# dtype: object

# %% [markdown]
# 5. feladat

# %%
df['email'] = df['email'].astype(str)
df['email_length'] = df['email'].str.len()

df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %% [markdown]
# 6. feladat

# %%
df[df['country'] == 'Germany']
# Out:
#     customer_id first_name   last_name company                  address  \
# 1             2     Leonie      Köhler     NaN  Theodor-Heuss-Straße 34
# 35           36     Hannah   Schneider     NaN       Tauentzienstraße 8
# 36           37       Fynn  Zimmermann     NaN         Berger Straße 10
# 37           38     Niklas    Schröder     NaN      Barbarossastraße 19
#
#          city state  country postal_code             phone  fax  \
# 1   Stuttgart   NaN  Germany       70174  +49 0711 2842222  NaN
# 35     Berlin   NaN  Germany       10789  +49 030 26550280  NaN
# 36  Frankfurt   NaN  Germany       60316  +49 069 40598889  NaN
# 37     Berlin   NaN  Germany       10779   +49 030 2141444  NaN
#
#                         email  support_rep_id  email_length
# 1       leonekohler@surfeu.de               5            59
# 35  hannah.schneider@yahoo.de               5            59
# 36       fzimmermann@yahoo.de               3            59
# ...

# %% [markdown]
# 7. feladat

# %%
df[df['company'].isna()]
# Out:
#     customer_id first_name     last_name company  \
# 1             2     Leonie        Köhler     NaN
# 2             3   François      Tremblay     NaN
# 3             4      Bjørn        Hansen     NaN
# 5             6     Helena          Holý     NaN
# 6             7     Astrid        Gruber     NaN
# 7             8       Daan       Peeters     NaN
# 8             9       Kara       Nielsen     NaN
# 12           13   Fernanda         Ramos     NaN
# 17           18   Michelle        Brooks     NaN
# 19           20        Dan        Miller     NaN
# 20           21      Kathy         Chase     NaN
# 21           22    Heather       Leacock     NaN
# 22           23       John        Gordon     NaN
# 23           24      Frank       Ralston     NaN
# 24           25     Victor       Stevens     NaN
# 25           26    Richard    Cunningham     NaN
# 26           27    Patrick          Gray     NaN
# 27           28      Julia       Barnett     NaN
# ...

# %% [markdown]
# 8. Feladat

# %%
df[df['fax'].notna()]
# Out:
#     customer_id first_name    last_name  \
# 0             1       Luís    Gonçalves
# 4             5  František  Wichterlová
# 9            10    Eduardo      Martins
# 10           11  Alexandre        Rocha
# 11           12    Roberto      Almeida
# 12           13   Fernanda        Ramos
# 13           14       Mark      Philips
# 14           15   Jennifer     Peterson
# 15           16      Frank       Harris
# 16           17       Jack        Smith
# 17           18   Michelle       Brooks
# 18           19        Tim        Goyer
#
#                                              company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 4                                   JetBrains s.r.o.
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 12                                               NaN
# 13                                             Telus
# ...

# %% [markdown]
# 9. feladat

# %%
df[df['email'].str.contains('gmail.com')]
# Out:
#     customer_id first_name last_name company                address  \
# 2             3   François  Tremblay     NaN      1498 rue Bélanger
# 5             6     Helena      Holý     NaN          Rilská 3174/6
# 21           22    Heather   Leacock     NaN       120 S Orange Ave
# 23           24      Frank   Ralston     NaN  162 E Superior Street
# 27           28      Julia   Barnett     NaN            302 S 700 E
# 30           31     Martha      Silk     NaN  194A Chain Lake Drive
# 39           40  Dominique  Lefebvre     NaN         8, Rue Hanovre
# 52           53       Phil    Hughes     NaN           113 Lupus St
#
#               city state         country postal_code               phone  fax  \
# 2         Montréal    QC          Canada     H2G 1A7   +1 (514) 721-4711  NaN
# 5           Prague   NaN  Czech Republic       14300    +420 2 4177 0449  NaN
# 21         Orlando    FL             USA       32801   +1 (407) 999-7788  NaN
# ...

# %% [markdown]
# 10. feladat

# %%
df_subset = df[['customer_id', 'first_name', 'last_name', 'country', 'email', 'email_length']]

df_subset
# Out:
#     customer_id first_name     last_name         country  \
# 0             1       Luís     Gonçalves          Brazil
# 1             2     Leonie        Köhler         Germany
# 2             3   François      Tremblay          Canada
# 3             4      Bjørn        Hansen          Norway
# 4             5  František   Wichterlová  Czech Republic
# 5             6     Helena          Holý  Czech Republic
# 6             7     Astrid        Gruber         Austria
# 7             8       Daan       Peeters         Belgium
# 8             9       Kara       Nielsen         Denmark
# 9            10    Eduardo       Martins          Brazil
# 10           11  Alexandre         Rocha          Brazil
# 11           12    Roberto       Almeida          Brazil
# 12           13   Fernanda         Ramos          Brazil
# 13           14       Mark       Philips          Canada
# 14           15   Jennifer      Peterson          Canada
# ...

# %%
df_unique = df['country'].unique()
len(df_unique)
# Out:
# array(['Brazil', 'Germany', 'Canada', 'Norway', 'Czech Republic',
#        'Austria', 'Belgium', 'Denmark', 'USA', 'Portugal', 'France',
#        'Finland', 'Hungary', 'Ireland', 'Italy', 'Netherlands', 'Poland',
#        'Spain', 'Sweden', 'United Kingdom', 'Australia', 'Argentina',
#        'Chile', 'India'], dtype=object)

# %%
df['last_name_length'] = df['last_name'].str.len()
df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df[(df['country'] == 'Canada') & (df['last_name_length'] >= 6)]
# Out:
#     customer_id first_name last_name        company              address  \
# 2             3   François  Tremblay            NaN    1498 rue Bélanger
# 13           14       Mark   Philips          Telus       8210 111 ST NW
# 14           15   Jennifer  Peterson  Rogers Canada  700 W Pender Street
# 29           30     Edward   Francis            NaN     230 Elgin Street
# 31           32      Aaron  Mitchell            NaN   696 Osborne Street
# 32           33      Ellie  Sullivan            NaN       5112 48 Street
#
#            city state country postal_code              phone  \
# 2      Montréal    QC  Canada     H2G 1A7  +1 (514) 721-4711
# 13     Edmonton    AB  Canada     T6G 2C7  +1 (780) 434-4554
# 14    Vancouver    BC  Canada     V6C 1G8  +1 (604) 688-2255
# 29       Ottawa    ON  Canada     K2P 1L7  +1 (613) 234-3322
# 31     Winnipeg    MB  Canada     R3L 2B9  +1 (204) 452-6452
# 32  Yellowknife    NT  Canada     X1A 1N6  +1 (867) 920-2233
#
# ...

# %%
df['has_yahoo'] = df['email'].str.contains('yahoo.com', case=False, na=False)
df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df[df['country'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, company, address, city, state, country, postal_code, phone, fax, email, support_rep_id, email_length, last_name_length, has_yahoo]
# Index: []

# %%
df[(df['country'] == 'USA') & (df['fax'].notna())]
# Out:
#     customer_id first_name last_name                company  \
# 15           16      Frank    Harris            Google Inc.
# 16           17       Jack     Smith  Microsoft Corporation
# 17           18   Michelle    Brooks                    NaN
# 18           19        Tim     Goyer             Apple Inc.
#
#                       address           city state country postal_code  \
# 15  1600 Amphitheatre Parkway  Mountain View    CA     USA  94043-1351
# 16            1 Microsoft Way        Redmond    WA     USA  98052-8300
# 17               627 Broadway       New York    NY     USA  10012-2612
# 18            1 Infinite Loop      Cupertino    CA     USA       95014
#
#                 phone                fax                    email  \
# 15  +1 (650) 253-0000  +1 (650) 253-0000       fharris@google.com
# 16  +1 (425) 882-8080  +1 (425) 882-8081  jacksmith@microsoft.com
# 17  +1 (212) 221-3546  +1 (212) 221-4679        michelleb@aol.com
# ...

# %%
df['first_name_length'] = df['first_name'].str.len() > 5
df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df["has_hotmail"] = df['email'].str.contains('hotmail.com', case=False, na=False)
df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
print(df[['company', 'fax']].isna().sum())
# Out:
# company    49
# fax        47
# dtype: int64

# %%
sub_df = df[['customer_id', 'first_name', 'last_name', 'email', 'country']]
sub_df
# Out:
#     customer_id first_name     last_name                          email  \
# 0             1       Luís     Gonçalves           luisg@embraer.com.br
# 1             2     Leonie        Köhler          leonekohler@surfeu.de
# 2             3   François      Tremblay            ftremblay@gmail.com
# 3             4      Bjørn        Hansen          bjorn.hansen@yahoo.no
# 4             5  František   Wichterlová       frantisekw@jetbrains.com
# 5             6     Helena          Holý                hholy@gmail.com
# 6             7     Astrid        Gruber         astrid.gruber@apple.at
# 7             8       Daan       Peeters          daan_peeters@apple.be
# 8             9       Kara       Nielsen          kara.nielsen@jubii.dk
# 9            10    Eduardo       Martins       eduardo@woodstock.com.br
# 10           11  Alexandre         Rocha               alero@uol.com.br
# 11           12    Roberto       Almeida  roberto.almeida@riotur.gov.br
# ...

# %% [markdown]
# Practice_sess_warmup_2025.02.26

# %%
import pandas as pd

df = pd.read_csv("customer.csv")

df.head(10)
# Out:
#    customer_id first_name    last_name  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
# 5            6     Helena         Holý
# 6            7     Astrid       Gruber
# 7            8       Daan      Peeters
# 8            9       Kara      Nielsen
# 9           10    Eduardo      Martins
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# ...

# %%
df['company'].nunique()
# Out:
# 10

# %%
df[df['last_name'].str.startswith("A")]
# Out:
#     customer_id first_name last_name company           address  \
# 11           12    Roberto   Almeida  Riotur  Praça Pio X, 119
#
#               city state country postal_code               phone  \
# 11  Rio de Janeiro    RJ  Brazil   20040-020  +55 (21) 2271-7000
#
#                    fax                          email  support_rep_id  \
# 11  +55 (21) 2271-7070  roberto.almeida@riotur.gov.br               3
#
#     customer_name_length
# 11                     7

# %%
df.duplicated(subset=['company']).sum()
# Out:
# np.int64(48)

# %%
df['customer_name_length'] = df['first_name'].str.len()

df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df.tail(5)
# Out:
#     customer_id first_name   last_name company              address  \
# 54           55       Mark      Taylor     NaN    421 Bourke Street
# 55           56      Diego   Gutiérrez     NaN   307 Macacha Güemes
# 56           57       Luis       Rojas     NaN      Calle Lira, 198
# 57           58      Manoj      Pareek     NaN  12,Community Centre
# 58           59       Puja  Srivastava     NaN    3,Raj Bhavan Road
#
#             city state    country postal_code                phone  fax  \
# 54        Sidney   NSW  Australia        2010   +61 (02) 9332 3633  NaN
# 55  Buenos Aires   NaN  Argentina        1106  +54 (0)11 4311 4333  NaN
# 56      Santiago   NaN      Chile         NaN    +56 (0)2 635 4444  NaN
# 57         Delhi   NaN      India      110017    +91 0124 39883988  NaN
# 58     Bangalore   NaN      India      560001     +91 080 22289999  NaN
#
#                        email  support_rep_id  customer_name_length
# ...

# %%
df['country'].nunique()
# Out:
# 24

# %%
df[df['email'].str.contains("yahoo", na=False)]
# Out:
#     customer_id first_name     last_name company                 address  \
# 3             4      Bjørn        Hansen     NaN        Ullevålsveien 14
# 22           23       John        Gordon     NaN         69 Salem Street
# 24           25     Victor       Stevens     NaN   319 N. Frances Street
# 31           32      Aaron      Mitchell     NaN      696 Osborne Street
# 33           34       João     Fernandes     NaN      Rua da Assunção 53
# 35           36     Hannah     Schneider     NaN      Tauentzienstraße 8
# 36           37       Fynn    Zimmermann     NaN        Berger Straße 10
# 38           39    Camille       Bernard     NaN           4, Rue Milton
# 41           42      Wyatt        Girard     NaN  9, Place Louis Barthou
# 46           47      Lucas       Mancini     NaN  Via Degli Scipioni, 43
# 47           48   Johannes  Van der Berg     NaN   Lijnbaansgracht 120bg
# 49           50    Enrique         Muñoz     NaN      C/ San Bernardo 85
# ...

# %%
df['phone'].isna().sum()
# Out:
# np.int64(1)

# %%
(df['first_name'].str.len() > 6).sum()
# Out:
# np.int64(19)

# %%
df[df['first_name'].str.len() == 5]
# Out:
#     customer_id first_name   last_name      company  \
# 3             4      Bjørn      Hansen          NaN
# 15           16      Frank      Harris  Google Inc.
# 20           21      Kathy       Chase          NaN
# 23           24      Frank     Ralston          NaN
# 27           28      Julia     Barnett          NaN
# 31           32      Aaron    Mitchell          NaN
# 32           33      Ellie    Sullivan          NaN
# 41           42      Wyatt      Girard          NaN
# 43           44      Terhi  Hämäläinen          NaN
# 46           47      Lucas     Mancini          NaN
# 53           54      Steve      Murray          NaN
# 55           56      Diego   Gutiérrez          NaN
# 57           58      Manoj      Pareek          NaN
#
#                       address            city state         country  \
# 3            Ullevålsveien 14            Oslo   NaN          Norway
# 15  1600 Amphitheatre Parkway   Mountain View    CA             USA
# ...

# %%
(df['company'] == 'Microsoft').sum()
# Out:
# np.int64(0)

# %%
df[df['country'].str.startswith('United')]
# Out:
#     customer_id first_name last_name company            address       city  \
# 51           52       Emma     Jones     NaN  202 Hoxton Street     London
# 52           53       Phil    Hughes     NaN       113 Lupus St     London
# 53           54      Steve    Murray     NaN     110 Raeburn Pl  Edinburgh
#
#    state         country postal_code              phone  fax  \
# 51   NaN  United Kingdom      N1 5LH  +44 020 7707 0707  NaN
# 52   NaN  United Kingdom    SW1V 3EN  +44 020 7976 5722  NaN
# 53   NaN  United Kingdom     EH4 1HH  +44 0131 315 3300  NaN
#
#                      email  support_rep_id  customer_name_length
# 51  emma_jones@hotmail.com               3                     4
# 52   phil.hughes@gmail.com               3                     4
# 53   steve.murray@yahoo.uk               5                     5

# %%
df[df['phone'].isna() | df['email'].isna()]
# Out:
#     customer_id first_name last_name company            address      city  \
# 44           45   Ladislav    Kovács     NaN  Erzsébet krt. 58.  Budapest
#
#    state  country postal_code phone  fax                     email  \
# 44   NaN  Hungary      H-1073   NaN  NaN  ladislav_kovacs@apple.hu
#
#     support_rep_id  customer_name_length
# 44               3                     8

# %%
(df['last_name'].value_counts()).gt(1).sum()
# Out:
# np.int64(0)

# %% [markdown]
# Practice sess 2

# %%
import pandas as pd

df = pd.read_csv('customer.csv')

# %%
df.head(10)
# Out:
#    customer_id first_name    last_name  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
# 5            6     Helena         Holý
# 6            7     Astrid       Gruber
# 7            8       Daan      Peeters
# 8            9       Kara      Nielsen
# 9           10    Eduardo      Martins
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# ...

# %%
df['country'].nunique()
# Out:
# 24

# %%
df['phone'].isna().sum()
# Out:
# np.int64(1)

# %%
df[df['email'].str.contains('gmail.com', na=False)]
# Out:
#     customer_id first_name last_name company                address  \
# 2             3   François  Tremblay     NaN      1498 rue Bélanger
# 5             6     Helena      Holý     NaN          Rilská 3174/6
# 21           22    Heather   Leacock     NaN       120 S Orange Ave
# 23           24      Frank   Ralston     NaN  162 E Superior Street
# 27           28      Julia   Barnett     NaN            302 S 700 E
# 30           31     Martha      Silk     NaN  194A Chain Lake Drive
# 39           40  Dominique  Lefebvre     NaN         8, Rue Hanovre
# 52           53       Phil    Hughes     NaN           113 Lupus St
#
#               city state         country postal_code               phone  fax  \
# 2         Montréal    QC          Canada     H2G 1A7   +1 (514) 721-4711  NaN
# 5           Prague   NaN  Czech Republic       14300    +420 2 4177 0449  NaN
# 21         Orlando    FL             USA       32801   +1 (407) 999-7788  NaN
# ...

# %%
df['last_name_length'] = df['last_name'].str.len()

df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df.tail(7)
# Out:
#     customer_id first_name   last_name company              address  \
# 52           53       Phil      Hughes     NaN         113 Lupus St
# 53           54      Steve      Murray     NaN       110 Raeburn Pl
# 54           55       Mark      Taylor     NaN    421 Bourke Street
# 55           56      Diego   Gutiérrez     NaN   307 Macacha Güemes
# 56           57       Luis       Rojas     NaN      Calle Lira, 198
# 57           58      Manoj      Pareek     NaN  12,Community Centre
# 58           59       Puja  Srivastava     NaN    3,Raj Bhavan Road
#
#             city state         country postal_code                phone  fax  \
# 52        London   NaN  United Kingdom    SW1V 3EN    +44 020 7976 5722  NaN
# 53     Edinburgh   NaN  United Kingdom     EH4 1HH    +44 0131 315 3300  NaN
# 54        Sidney   NSW       Australia        2010   +61 (02) 9332 3633  NaN
# 55  Buenos Aires   NaN       Argentina        1106  +54 (0)11 4311 4333  NaN
# ...

# %%
df['company'].isna().sum()
# Out:
# np.int64(49)

# %%
df[df['first_name'].str.startswith('J')]
# Out:
#     customer_id first_name     last_name                company  \
# 14           15   Jennifer      Peterson          Rogers Canada
# 16           17       Jack         Smith  Microsoft Corporation
# 22           23       John        Gordon                    NaN
# 27           28      Julia       Barnett                    NaN
# 33           34       João     Fernandes                    NaN
# 47           48   Johannes  Van der Berg                    NaN
# 50           51     Joakim     Johansson                    NaN
#
#                   address            city state      country postal_code  \
# 14    700 W Pender Street       Vancouver    BC       Canada     V6C 1G8
# 16        1 Microsoft Way         Redmond    WA          USA  98052-8300
# 22        69 Salem Street          Boston    MA          USA        2113
# 27            302 S 700 E  Salt Lake City    UT          USA       84102
# 33     Rua da Assunção 53          Lisbon   NaN     Portugal         NaN
# ...

# %%
df['phone'].str.contains(r'\+1').sum()
# Out:
# 21

# %%
df['full_name_length'] = df['first_name'].str.len() + df['last_name'].str.len()

df
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
import pandas as pd

task_df = pd.DataFrame({'Név': ["Joci", "Zsola", "Anna"], 'Kor': [30, 25, 19]})

task_df
# Out:
#      Név  Kor
# 0   Joci   30
# 1  Zsola   25
# 2   Anna   19

# %%
df1 = pd.read_csv("customer.csv")
df1.head(5)
# Out:
#    customer_id first_name    last_name  \
# 0            1       Luís    Gonçalves
# 1            2     Leonie       Köhler
# 2            3   François     Tremblay
# 3            4      Bjørn       Hansen
# 4            5  František  Wichterlová
#
#                                             company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
#
#                            address                 city state         country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo   NaN          Norway
# ...

# %%
df1.shape[1]
# Out:
# 13

# %%
df1[df1['country'] == 'USA']
# Out:
#     customer_id first_name   last_name                company  \
# 15           16      Frank      Harris            Google Inc.
# 16           17       Jack       Smith  Microsoft Corporation
# 17           18   Michelle      Brooks                    NaN
# 18           19        Tim       Goyer             Apple Inc.
# 19           20        Dan      Miller                    NaN
# 20           21      Kathy       Chase                    NaN
# 21           22    Heather     Leacock                    NaN
# 22           23       John      Gordon                    NaN
# 23           24      Frank     Ralston                    NaN
# 24           25     Victor     Stevens                    NaN
# 25           26    Richard  Cunningham                    NaN
# 26           27    Patrick        Gray                    NaN
# 27           28      Julia     Barnett                    NaN
#
#                       address            city state country postal_code  \
# ...

# %%
df1['name_length'] = df1['first_name'].str.len() + df1['last_name'].str.len()

df1
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df1.tail(8)
# Out:
#     customer_id first_name   last_name company              address  \
# 51           52       Emma       Jones     NaN    202 Hoxton Street
# 52           53       Phil      Hughes     NaN         113 Lupus St
# 53           54      Steve      Murray     NaN       110 Raeburn Pl
# 54           55       Mark      Taylor     NaN    421 Bourke Street
# 55           56      Diego   Gutiérrez     NaN   307 Macacha Güemes
# 56           57       Luis       Rojas     NaN      Calle Lira, 198
# 57           58      Manoj      Pareek     NaN  12,Community Centre
# 58           59       Puja  Srivastava     NaN    3,Raj Bhavan Road
#
#             city state         country postal_code                phone  fax  \
# 51        London   NaN  United Kingdom      N1 5LH    +44 020 7707 0707  NaN
# 52        London   NaN  United Kingdom    SW1V 3EN    +44 020 7976 5722  NaN
# 53     Edinburgh   NaN  United Kingdom     EH4 1HH    +44 0131 315 3300  NaN
# ...

# %%
df1['country'].nunique()
# Out:
# 24

# %%
df1[df1['first_name'].str.len() <= 4 ]
# Out:
#     customer_id first_name   last_name  \
# 0             1       Luís   Gonçalves
# 7             8       Daan     Peeters
# 8             9       Kara     Nielsen
# 13           14       Mark     Philips
# 16           17       Jack       Smith
# 18           19        Tim       Goyer
# 19           20        Dan      Miller
# 22           23       John      Gordon
# 33           34       João   Fernandes
# 36           37       Fynn  Zimmermann
# 40           41       Marc      Dubois
# 45           46       Hugh    O'Reilly
# 51           52       Emma       Jones
# 52           53       Phil      Hughes
# 54           55       Mark      Taylor
# 56           57       Luis       Rojas
# 58           59       Puja  Srivastava
#
#                                              company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 7                                                NaN
# 8                                                NaN
# ...

# %%
df1['email'].isna().sum()
# Out:
# np.int64(0)

# %%
df1['has_company'] = df1['company'].notna()

df1
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
df1[df1['country'] == 'Canada']
# Out:
#     customer_id first_name last_name        company                 address  \
# 2             3   François  Tremblay            NaN       1498 rue Bélanger
# 13           14       Mark   Philips          Telus          8210 111 ST NW
# 14           15   Jennifer  Peterson  Rogers Canada     700 W Pender Street
# 28           29     Robert     Brown            NaN  796 Dundas Street West
# 29           30     Edward   Francis            NaN        230 Elgin Street
# 30           31     Martha      Silk            NaN   194A Chain Lake Drive
# 31           32      Aaron  Mitchell            NaN      696 Osborne Street
# 32           33      Ellie  Sullivan            NaN          5112 48 Street
#
#            city state country postal_code              phone  \
# 2      Montréal    QC  Canada     H2G 1A7  +1 (514) 721-4711
# 13     Edmonton    AB  Canada     T6G 2C7  +1 (780) 434-4554
# 14    Vancouver    BC  Canada     V6C 1G8  +1 (604) 688-2255
# ...

# %%
df1[df1['email'].str.endswith('yahoo.com')]
# Out:
#     customer_id first_name last_name company                address     city  \
# 22           23       John    Gordon     NaN        69 Salem Street   Boston
# 24           25     Victor   Stevens     NaN  319 N. Frances Street  Madison
#
#    state country postal_code              phone  fax                   email  \
# 22    MA     USA        2113  +1 (617) 522-1333  NaN  johngordon22@yahoo.com
# 24    WI     USA       53703  +1 (608) 257-0597  NaN      vstevens@yahoo.com
#
#     support_rep_id  name_length  has_company
# 22               4           10        False
# 24               5           13        False

# %%
df1[df1['phone'].isna()]
# Out:
#     customer_id first_name last_name company            address      city  \
# 44           45   Ladislav    Kovács     NaN  Erzsébet krt. 58.  Budapest
#
#    state  country postal_code phone  fax                     email  \
# 44   NaN  Hungary      H-1073   NaN  NaN  ladislav_kovacs@apple.hu
#
#     support_rep_id  name_length  has_company
# 44               3           14        False

# %%
df1[(df1['country'] == 'USA') | (df1['country'] =='Canada')]
# Out:
#     customer_id first_name   last_name                company  \
# 2             3   François    Tremblay                    NaN
# 13           14       Mark     Philips                  Telus
# 14           15   Jennifer    Peterson          Rogers Canada
# 15           16      Frank      Harris            Google Inc.
# 16           17       Jack       Smith  Microsoft Corporation
# 17           18   Michelle      Brooks                    NaN
# 18           19        Tim       Goyer             Apple Inc.
# 19           20        Dan      Miller                    NaN
# 20           21      Kathy       Chase                    NaN
# 21           22    Heather     Leacock                    NaN
# 22           23       John      Gordon                    NaN
# 23           24      Frank     Ralston                    NaN
# 24           25     Victor     Stevens                    NaN
# 25           26    Richard  Cunningham                    NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('track.csv')

df
# Out:
#       track_id                                               name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# ...
